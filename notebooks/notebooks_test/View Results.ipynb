# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

import numpy as np
import os

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# This notebook loads saved results from recon.show()

# %%
os.listdir('./')
# Out:
# ['sandbox_background.ipynb',
#  'sandbox_alpha_blending.ipynb',
#  'sandbox_regularization.ipynb',
#  'path_simulation_analysis.ipynb',
#  'conferences',
#  'sandbox_normalization.ipynb',
#  'sandbox_blur_kernel_inversion.ipynb',
#  'sandbox_single_frame.ipynb',
#  'View Results.ipynb',
#  'autocalibration-simulated-real-data.ipynb',
#  'test_reconstructions.py',
#  '0tmp.png',
#  '.ipynb_checkpoints',
#  'restarget_registration_motiondeblur.ipynb',
#  'sandbox_arrayfire_orb.ipynb',
#  'restarget_direct_inversion_motiondeblur.ipynb',
#  'singleframe_registration_multiframe_autocal.ipynb',
#  'Exploring Registration Limits.ipynb',
#  'Denoiser Object Tests.ipynb',
#  'sandbox_registration.ipynb',
#  'sequential-recovery.ipynb',
#  'sandbox_reconstruction.ipynb',
#  'sandbox_terastitch.ipynb',
#  'alternating_min_real_data.ipynb',
#  '__pycache__',
#  'Motion Path Fitting with Splines.ipynb']

# %%
recon = plt.imread('1tmp.png')
plt.imshow(recon)
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">
