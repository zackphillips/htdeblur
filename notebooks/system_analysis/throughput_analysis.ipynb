# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from libwallerlab.opticsalgorithms.motiondeblur import blurkernel
# Out:
# /Users/zfphil/anaconda3/lib/python3.6/site-packages/skimage/viewer/utils/core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "

# %% [markdown]
# # Overview
# This notebook explores a SNR vs. acquisition time analysis for strobed illumination, stop and stare, and coded illumination acquisition strategies.
#
# First, we determine a relationship between t_frame (frame rate) and t_exposure (exposure time). Then, we relate t_exposure to SNR for each method. These relationships should be smooth but non-linear.

# %%
# Define constants
ps = 6.5e-3 #mm
mag = 20
ps_eff = ps / mag #um
n_px = np.asarray([2100, 2500])
fov = n_px * ps_eff
motion_axis = 0
motion_velocity_mm_s = 20
motion_acceleration_mm_s_s = 1e4

t_settle = 0.1   #s
t_ro     = 0.01  #s

figure_directory = '/Users/zfphil/Desktop/figures/'
# !mkdir -p /Users/zfphil/Desktop/figures/

# %%
np.random.choice(10)
# Out:
# 4

# %%
def genBlurVector_rand(kernel_length, beta=0.5, n_tests=10, metric='dnf'):
    '''
    This is a helper function for solving for a blur vector in terms of it's condition #
    '''
    kernel_list = []
    n_elements_max = math.floor(beta * kernel_length)
    for test in range(n_tests):
        indicies = np.random.permutation(kernel_length)
        kernel = np.zeros(kernel_length)
        kernel[indicies[:n_elements_max]] = 1.0
        
#         indicies = np.arange(kernel_length)
#         for index in range(n_elements_max):
#             rand_index = np.random.randint(0, high=np.size(indicies)-1, size=1)
#             kernel[indicies[rand_index]] = 1.
#             indicies = np.delete(indicies, rand_index)

        rand_index = np.random.permutation(kernel_length)[n_elements_max]
        kernel[rand_index] = beta * kernel_length - np.sum(kernel)
        assert beta * kernel_length - np.sum(kernel) <= 1
        kernel_list.append(kernel)

    if metric == 'cond':
        # Determine kernel with best conditioon #
        metric_best = 1e10
        kernel_best = []
        for kernel in kernel_list:
            spectra = np.abs(np.fft.fft(kernel))
            kappa = np.max(spectra) / np.min(spectra)
            if kappa < metric_best:
                kernel_best = kernel
                metric_best = kappa
    else:
        # Determine kernel with best conditioon #
        metric_best = 1e10
        kernel_best = []
        for kernel in kernel_list:
            dnf = (np.sum(1 / np.abs(scipy.fftpack.fft(kernel)) ** 2))
            if dnf < metric_best:
                kernel_best = kernel
                metric_best = dnf

    return (metric_best, kernel_best)

# import math
# def condNumToDnf(cond, blur_length, image_size, beta=0.1):
#     dnf = ((blur_length * beta) ** 2 / cond ** 2) * math.sqrt(np.prod(image_size))
#     return dnf
    
# # condNumToDnf(40, 50, (1000,1000))
import scipy
def calcDnfFromKernel(x):
    from libwallerlab.utilities.opticstools import Ft, iFt
    return (np.sum(1 / np.abs(scipy.fftpack.fft(x)) ** 2))

def getOptimalDnf(kernel_size, beta=0.5, n_tests=100, metric = 'dnf'):
    dnf, x = genBlurVector_rand(100, beta=beta, n_tests=n_tests, metric=metric)
    return(calcDnfFromKernel(x))

# %%
getOptimalDnf(100, n_tests=200, metric='dnf')
# Out:
# /Users/zfphil/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:38: RuntimeWarning: divide by zero encountered in true_divide
# 8.265637230463955

# %%
def frameRateToExposure(t_frame, acquisition_strategy, motion_velocity_mm_s=10, 
                        motion_acceleration_mm_s_s=1e4, t_readout=0.01, t_settle=0.1, 
                        fov=[1,1], motion_axis=0, ps_eff_mm=6.5e-3/20, beta_coded=0.5,
                        min_strobe_time_s=10e-6):
    

    if 'strobe' in acquisition_strategy:
        t_exp_camera = t_frame - t_readout
        v = fov[motion_axis] / t_frame
        t_illum_strobe = ps_eff / v
        if t_illum_strobe < min_strobe_time_s:
            t_exp = 0
        else:
            t_exp = t_illum_strobe
            
        # No deconvolution here
        dnf = 1
        
    elif 'stop_and_stare' in acquisition_strategy:
        t_start_stop = motion_velocity_mm_s / motion_acceleration_mm_s_s
        d_start_stop = 0.5 * motion_acceleration_mm_s_s * t_start_stop ** 2 
        t_move = (fov[motion_axis] - d_start_stop) / motion_velocity_mm_s
        t_exp_camera = t_frame - t_move - t_start_stop + t_readout
        t_exp = t_exp_camera # Illumination is on the whole time
        
        # No deconvolution here
        dnf = 1
        
    elif 'code' in acquisition_strategy:
        t_exp_camera = t_frame - t_readout
        
        # Determine kernel length
        kernel_length = int(np.ceil(t_exp_camera / t_frame * fov[motion_axis] / ps_eff))
        kernel_length = max(kernel_length, 1)
        
        if kernel_length == 1:
            dnf = 1
        else:
#             dnf = blurkernel.dnfUpperBound(kernel_length, beta_coded)
            dnf = getOptimalDnf(kernel_length, beta=beta_coded, n_tests=10)
        
        t_exp_camera = t_frame - t_readout
        v = fov[motion_axis] / t_frame
        t_illum_strobe = ps_eff / v
        if t_illum_strobe < min_strobe_time_s:
            t_exp = 0
        else:
            t_exp = t_exp_camera * beta_coded
        
# #     assert t_exp > 0
    if t_exp <= 0 or t_exp_camera <= 0:
        t_exp = 0

        
    return(t_exp, dnf)

frame_time = 0.1
t_strobe, dnf_strobd = frameRateToExposure(frame_time, 'strobe', fov=fov)
snr_strobe = blurkernel.dnf2snr(dnf_strobd, t_strobe*1000)
print("Strobed illumination will have exposure time %.5f seconds and SNR %.5f" % (t_strobe, snr_strobe))

t_sns, dnf_sns = frameRateToExposure(frame_time, 'stop_and_stare', fov=fov)
snr_sns = blurkernel.dnf2snr(dnf_sns, t_sns*1000)
print("Stop-and-stare illumination will have exposure time %.5f seconds and SNR %.5f" % (t_sns, snr_sns))

t_coded, dnf_coded = frameRateToExposure(frame_time, 'code', fov=fov)
snr_coded = blurkernel.dnf2snr(dnf_coded, t_coded*1000)
print("Coded illumination will have exposure time %.5f seconds and SNR %.5f" % (t_coded, snr_coded))
# Out:
# Strobed illumination will have exposure time 0.00005 seconds and SNR 11.75121
# Stop-and-stare illumination will have exposure time 0.04125 seconds and SNR 351.61446
# Coded illumination will have exposure time 0.04500 seconds and SNR 27.58764
# /Users/zfphil/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:38: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# ## Plot SNR vs Frame Rate

# %%
frame_rates = np.arange(1,80,0.1)
snr_strobe_list = []
snr_sns_list = []
snr_coded_list_25 = []
snr_coded_list_10 = []
snr_coded_list_50 = []
snr_coded_list_75 = []
snr_coded_list_99 = []

for index, rate in enumerate(frame_rates):
    t_frame = 1 / rate
    
    t_strobe, dnf_strobe = frameRateToExposure(t_frame, 'strobe', fov=fov)
    snr_strobe_list.append(blurkernel.dnf2snr(dnf_strobe, t_strobe*1000))

    t_sns, dnf_sns = frameRateToExposure(t_frame, 'stop_and_stare', fov=fov)
    snr_sns_list.append(blurkernel.dnf2snr(dnf_sns, t_sns*1000))

    t_coded_10, dnf_coded_10 = frameRateToExposure(t_frame, 'code', fov=fov, beta_coded=0.05)
    snr_coded_list_10.append(blurkernel.dnf2snr(dnf_coded_10, t_coded_10*1000))
    
    t_coded_50, dnf_coded_50 = frameRateToExposure(t_frame, 'code', fov=fov, beta_coded=0.5)
    snr_coded_list_50.append(blurkernel.dnf2snr(dnf_coded_50, t_coded_50*1000))
    
#     t_coded_75, dnf_coded_75 = frameRateToExposure(t_frame, 'code', fov=fov, beta_coded=0.75)
#     snr_coded_list_75.append(blurkernel.dnf2snr(dnf_coded_75, t_coded_75))
    
    t_coded_99, dnf_coded_99 = frameRateToExposure(t_frame, 'code', fov=fov, beta_coded=0.95)
    snr_coded_list_99.append(blurkernel.dnf2snr(dnf_coded_99, t_coded_99*1000))
#     snr_coded_list.append(0)
#     print("Coded illumination will have exposure time %.3f seconds and SNR %.2f" % (t_coded, snr_coded))
#     print("Finished rate %d of %d" % (index, len(frame_rates)))
# Out:
# /Users/zfphil/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:38: RuntimeWarning: divide by zero encountered in true_divide
# Finished rate 0 of 790
# Finished rate 1 of 790
# Finished rate 2 of 790
# Finished rate 3 of 790
# Finished rate 4 of 790
# Finished rate 5 of 790
# Finished rate 6 of 790
# Finished rate 7 of 790
# Finished rate 8 of 790
# Finished rate 9 of 790
# Finished rate 10 of 790
# Finished rate 11 of 790
# Finished rate 12 of 790
# Finished rate 13 of 790
# Finished rate 14 of 790
# Finished rate 15 of 790
# Finished rate 16 of 790
# Finished rate 17 of 790
# Finished rate 18 of 790
# Finished rate 19 of 790
# Finished rate 20 of 790
# Finished rate 21 of 790
# Finished rate 22 of 790
# Finished rate 23 of 790
# Finished rate 24 of 790
# Finished rate 25 of 790
# Finished rate 26 of 790
# Finished rate 27 of 790
# Finished rate 28 of 790
# Finished rate 29 of 790
# Finished rate 30 of 790
# Finished rate 31 of 790
# Finished rate 32 of 790
# Finished rate 33 of 790
# Finished rate 34 of 790
# Finished rate 35 of 790
# Finished rate 36 of 790
# Finished rate 37 of 790
# Finished rate 38 of 790
# Finished rate 39 of 790
# Finished rate 40 of 790
# Finished rate 41 of 790
# Finished rate 42 of 790
# Finished rate 43 of 790
# Finished rate 44 of 790
# Finished rate 45 of 790
# Finished rate 46 of 790
# Finished rate 47 of 790
# Finished rate 48 of 790
# Finished rate 49 of 790
# Finished rate 50 of 790
# Finished rate 51 of 790
# Finished rate 52 of 790
# Finished rate 53 of 790
# Finished rate 54 of 790
# Finished rate 55 of 790
# Finished rate 56 of 790
# Finished rate 57 of 790
# Finished rate 58 of 790
# Finished rate 59 of 790
# Finished rate 60 of 790
# Finished rate 61 of 790
# Finished rate 62 of 790
# Finished rate 63 of 790
# Finished rate 64 of 790
# Finished rate 65 of 790
# Finished rate 66 of 790
# Finished rate 67 of 790
# Finished rate 68 of 790
# Finished rate 69 of 790
# Finished rate 70 of 790
# Finished rate 71 of 790
# Finished rate 72 of 790
# Finished rate 73 of 790
# Finished rate 74 of 790
# Finished rate 75 of 790
# Finished rate 76 of 790
# Finished rate 77 of 790
# Finished rate 78 of 790
# Finished rate 79 of 790
# Finished rate 80 of 790
# Finished rate 81 of 790
# Finished rate 82 of 790
# Finished rate 83 of 790
# Finished rate 84 of 790
# Finished rate 85 of 790
# Finished rate 86 of 790
# Finished rate 87 of 790
# Finished rate 88 of 790
# Finished rate 89 of 790
# Finished rate 90 of 790
# Finished rate 91 of 790
# Finished rate 92 of 790
# Finished rate 93 of 790
# Finished rate 94 of 790
# Finished rate 95 of 790
# Finished rate 96 of 790
# Finished rate 97 of 790
# Finished rate 98 of 790
# Finished rate 99 of 790
# Finished rate 100 of 790
# Finished rate 101 of 790
# Finished rate 102 of 790
# Finished rate 103 of 790
# Finished rate 104 of 790
# Finished rate 105 of 790
# Finished rate 106 of 790
# Finished rate 107 of 790
# Finished rate 108 of 790
# Finished rate 109 of 790
# Finished rate 110 of 790
# Finished rate 111 of 790
# Finished rate 112 of 790
# Finished rate 113 of 790
# Finished rate 114 of 790
# Finished rate 115 of 790
# Finished rate 116 of 790
# Finished rate 117 of 790
# Finished rate 118 of 790
# Finished rate 119 of 790
# Finished rate 120 of 790
# Finished rate 121 of 790
# Finished rate 122 of 790
# Finished rate 123 of 790
# Finished rate 124 of 790
# Finished rate 125 of 790
# Finished rate 126 of 790
# Finished rate 127 of 790
# Finished rate 128 of 790
# Finished rate 129 of 790
# Finished rate 130 of 790
# Finished rate 131 of 790
# Finished rate 132 of 790
# Finished rate 133 of 790
# Finished rate 134 of 790
# Finished rate 135 of 790
# Finished rate 136 of 790
# Finished rate 137 of 790
# Finished rate 138 of 790
# Finished rate 139 of 790
# Finished rate 140 of 790
# Finished rate 141 of 790
# Finished rate 142 of 790
# Finished rate 143 of 790
# Finished rate 144 of 790
# Finished rate 145 of 790
# Finished rate 146 of 790
# Finished rate 147 of 790
# Finished rate 148 of 790
# Finished rate 149 of 790
# Finished rate 150 of 790
# Finished rate 151 of 790
# Finished rate 152 of 790
# Finished rate 153 of 790
# Finished rate 154 of 790
# Finished rate 155 of 790
# Finished rate 156 of 790
# Finished rate 157 of 790
# Finished rate 158 of 790
# Finished rate 159 of 790
# Finished rate 160 of 790
# Finished rate 161 of 790
# Finished rate 162 of 790
# Finished rate 163 of 790
# Finished rate 164 of 790
# Finished rate 165 of 790
# Finished rate 166 of 790
# Finished rate 167 of 790
# Finished rate 168 of 790
# Finished rate 169 of 790
# Finished rate 170 of 790
# Finished rate 171 of 790
# Finished rate 172 of 790
# Finished rate 173 of 790
# Finished rate 174 of 790
# Finished rate 175 of 790
# Finished rate 176 of 790
# Finished rate 177 of 790
# Finished rate 178 of 790
# Finished rate 179 of 790
# Finished rate 180 of 790
# Finished rate 181 of 790
# Finished rate 182 of 790
# Finished rate 183 of 790
# Finished rate 184 of 790
# Finished rate 185 of 790
# Finished rate 186 of 790
# Finished rate 187 of 790
# Finished rate 188 of 790
# Finished rate 189 of 790
# Finished rate 190 of 790
# Finished rate 191 of 790
# Finished rate 192 of 790
# Finished rate 193 of 790
# Finished rate 194 of 790
# Finished rate 195 of 790
# Finished rate 196 of 790
# Finished rate 197 of 790
# Finished rate 198 of 790
# Finished rate 199 of 790
# Finished rate 200 of 790
# Finished rate 201 of 790
# Finished rate 202 of 790
# Finished rate 203 of 790
# Finished rate 204 of 790
# Finished rate 205 of 790
# Finished rate 206 of 790
# Finished rate 207 of 790
# Finished rate 208 of 790
# Finished rate 209 of 790
# Finished rate 210 of 790
# Finished rate 211 of 790
# Finished rate 212 of 790
# Finished rate 213 of 790
# Finished rate 214 of 790
# Finished rate 215 of 790
# Finished rate 216 of 790
# Finished rate 217 of 790
# Finished rate 218 of 790
# Finished rate 219 of 790
# Finished rate 220 of 790
# Finished rate 221 of 790
# Finished rate 222 of 790
# Finished rate 223 of 790
# Finished rate 224 of 790
# Finished rate 225 of 790
# Finished rate 226 of 790
# Finished rate 227 of 790
# Finished rate 228 of 790
# Finished rate 229 of 790
# Finished rate 230 of 790
# Finished rate 231 of 790
# Finished rate 232 of 790
# Finished rate 233 of 790
# Finished rate 234 of 790
# Finished rate 235 of 790
# Finished rate 236 of 790
# Finished rate 237 of 790
# Finished rate 238 of 790
# Finished rate 239 of 790
# Finished rate 240 of 790
# Finished rate 241 of 790
# Finished rate 242 of 790
# Finished rate 243 of 790
# Finished rate 244 of 790
# Finished rate 245 of 790
# Finished rate 246 of 790
# Finished rate 247 of 790
# Finished rate 248 of 790
# Finished rate 249 of 790
# Finished rate 250 of 790
# Finished rate 251 of 790
# Finished rate 252 of 790
# Finished rate 253 of 790
# Finished rate 254 of 790
# Finished rate 255 of 790
# Finished rate 256 of 790
# Finished rate 257 of 790
# Finished rate 258 of 790
# Finished rate 259 of 790
# Finished rate 260 of 790
# Finished rate 261 of 790
# Finished rate 262 of 790
# Finished rate 263 of 790
# Finished rate 264 of 790
# Finished rate 265 of 790
# Finished rate 266 of 790
# Finished rate 267 of 790
# Finished rate 268 of 790
# Finished rate 269 of 790
# Finished rate 270 of 790
# Finished rate 271 of 790
# Finished rate 272 of 790
# Finished rate 273 of 790
# Finished rate 274 of 790
# Finished rate 275 of 790
# Finished rate 276 of 790
# Finished rate 277 of 790
# Finished rate 278 of 790
# Finished rate 279 of 790
# Finished rate 280 of 790
# Finished rate 281 of 790
# Finished rate 282 of 790
# Finished rate 283 of 790
# Finished rate 284 of 790
# Finished rate 285 of 790
# Finished rate 286 of 790
# Finished rate 287 of 790
# Finished rate 288 of 790
# Finished rate 289 of 790
# Finished rate 290 of 790
# Finished rate 291 of 790
# Finished rate 292 of 790
# Finished rate 293 of 790
# Finished rate 294 of 790
# Finished rate 295 of 790
# Finished rate 296 of 790
# Finished rate 297 of 790
# Finished rate 298 of 790
# Finished rate 299 of 790
# Finished rate 300 of 790
# Finished rate 301 of 790
# Finished rate 302 of 790
# Finished rate 303 of 790
# Finished rate 304 of 790
# Finished rate 305 of 790
# Finished rate 306 of 790
# Finished rate 307 of 790
# Finished rate 308 of 790
# Finished rate 309 of 790
# Finished rate 310 of 790
# Finished rate 311 of 790
# Finished rate 312 of 790
# Finished rate 313 of 790
# Finished rate 314 of 790
# Finished rate 315 of 790
# Finished rate 316 of 790
# Finished rate 317 of 790
# Finished rate 318 of 790
# Finished rate 319 of 790
# Finished rate 320 of 790
# Finished rate 321 of 790
# Finished rate 322 of 790
# Finished rate 323 of 790
# Finished rate 324 of 790
# Finished rate 325 of 790
# Finished rate 326 of 790
# Finished rate 327 of 790
# Finished rate 328 of 790
# Finished rate 329 of 790
# Finished rate 330 of 790
# Finished rate 331 of 790
# Finished rate 332 of 790
# Finished rate 333 of 790
# Finished rate 334 of 790
# Finished rate 335 of 790
# Finished rate 336 of 790
# Finished rate 337 of 790
# Finished rate 338 of 790
# Finished rate 339 of 790
# Finished rate 340 of 790
# Finished rate 341 of 790
# Finished rate 342 of 790
# Finished rate 343 of 790
# Finished rate 344 of 790
# Finished rate 345 of 790
# Finished rate 346 of 790
# Finished rate 347 of 790
# Finished rate 348 of 790
# Finished rate 349 of 790
# Finished rate 350 of 790
# Finished rate 351 of 790
# Finished rate 352 of 790
# Finished rate 353 of 790
# Finished rate 354 of 790
# Finished rate 355 of 790
# Finished rate 356 of 790
# Finished rate 357 of 790
# Finished rate 358 of 790
# Finished rate 359 of 790
# Finished rate 360 of 790
# Finished rate 361 of 790
# Finished rate 362 of 790
# Finished rate 363 of 790
# Finished rate 364 of 790
# Finished rate 365 of 790
# Finished rate 366 of 790
# Finished rate 367 of 790
# Finished rate 368 of 790
# Finished rate 369 of 790
# Finished rate 370 of 790
# Finished rate 371 of 790
# Finished rate 372 of 790
# Finished rate 373 of 790
# Finished rate 374 of 790
# Finished rate 375 of 790
# Finished rate 376 of 790
# Finished rate 377 of 790
# Finished rate 378 of 790
# Finished rate 379 of 790
# Finished rate 380 of 790
# Finished rate 381 of 790
# Finished rate 382 of 790
# Finished rate 383 of 790
# Finished rate 384 of 790
# Finished rate 385 of 790
# Finished rate 386 of 790
# Finished rate 387 of 790
# Finished rate 388 of 790
# Finished rate 389 of 790
# Finished rate 390 of 790
# Finished rate 391 of 790
# Finished rate 392 of 790
# Finished rate 393 of 790
# Finished rate 394 of 790
# Finished rate 395 of 790
# Finished rate 396 of 790
# Finished rate 397 of 790
# Finished rate 398 of 790
# Finished rate 399 of 790
# Finished rate 400 of 790
# Finished rate 401 of 790
# Finished rate 402 of 790
# Finished rate 403 of 790
# Finished rate 404 of 790
# Finished rate 405 of 790
# Finished rate 406 of 790
# Finished rate 407 of 790
# Finished rate 408 of 790
# Finished rate 409 of 790
# Finished rate 410 of 790
# Finished rate 411 of 790
# Finished rate 412 of 790
# Finished rate 413 of 790
# Finished rate 414 of 790
# Finished rate 415 of 790
# Finished rate 416 of 790
# Finished rate 417 of 790
# Finished rate 418 of 790
# Finished rate 419 of 790
# Finished rate 420 of 790
# Finished rate 421 of 790
# Finished rate 422 of 790
# Finished rate 423 of 790
# Finished rate 424 of 790
# Finished rate 425 of 790
# Finished rate 426 of 790
# Finished rate 427 of 790
# Finished rate 428 of 790
# Finished rate 429 of 790
# Finished rate 430 of 790
# Finished rate 431 of 790
# Finished rate 432 of 790
# Finished rate 433 of 790
# Finished rate 434 of 790
# Finished rate 435 of 790
# Finished rate 436 of 790
# Finished rate 437 of 790
# Finished rate 438 of 790
# Finished rate 439 of 790
# Finished rate 440 of 790
# Finished rate 441 of 790
# Finished rate 442 of 790
# Finished rate 443 of 790
# Finished rate 444 of 790
# Finished rate 445 of 790
# Finished rate 446 of 790
# Finished rate 447 of 790
# Finished rate 448 of 790
# Finished rate 449 of 790
# Finished rate 450 of 790
# Finished rate 451 of 790
# Finished rate 452 of 790
# Finished rate 453 of 790
# Finished rate 454 of 790
# Finished rate 455 of 790
# Finished rate 456 of 790
# Finished rate 457 of 790
# Finished rate 458 of 790
# Finished rate 459 of 790
# Finished rate 460 of 790
# Finished rate 461 of 790
# Finished rate 462 of 790
# Finished rate 463 of 790
# Finished rate 464 of 790
# Finished rate 465 of 790
# Finished rate 466 of 790
# Finished rate 467 of 790
# Finished rate 468 of 790
# Finished rate 469 of 790
# Finished rate 470 of 790
# Finished rate 471 of 790
# Finished rate 472 of 790
# Finished rate 473 of 790
# Finished rate 474 of 790
# Finished rate 475 of 790
# Finished rate 476 of 790
# Finished rate 477 of 790
# Finished rate 478 of 790
# Finished rate 479 of 790
# Finished rate 480 of 790
# Finished rate 481 of 790
# Finished rate 482 of 790
# Finished rate 483 of 790
# Finished rate 484 of 790
# Finished rate 485 of 790
# Finished rate 486 of 790
# Finished rate 487 of 790
# Finished rate 488 of 790
# Finished rate 489 of 790
# Finished rate 490 of 790
# Finished rate 491 of 790
# Finished rate 492 of 790
# Finished rate 493 of 790
# Finished rate 494 of 790
# Finished rate 495 of 790
# Finished rate 496 of 790
# Finished rate 497 of 790
# Finished rate 498 of 790
# Finished rate 499 of 790
# Finished rate 500 of 790
# Finished rate 501 of 790
# Finished rate 502 of 790
# Finished rate 503 of 790
# Finished rate 504 of 790
# Finished rate 505 of 790
# Finished rate 506 of 790
# Finished rate 507 of 790
# Finished rate 508 of 790
# Finished rate 509 of 790
# Finished rate 510 of 790
# Finished rate 511 of 790
# Finished rate 512 of 790
# Finished rate 513 of 790
# Finished rate 514 of 790
# Finished rate 515 of 790
# Finished rate 516 of 790
# Finished rate 517 of 790
# Finished rate 518 of 790
# Finished rate 519 of 790
# Finished rate 520 of 790
# Finished rate 521 of 790
# Finished rate 522 of 790
# Finished rate 523 of 790
# Finished rate 524 of 790
# Finished rate 525 of 790
# Finished rate 526 of 790
# Finished rate 527 of 790
# Finished rate 528 of 790
# Finished rate 529 of 790
# Finished rate 530 of 790
# Finished rate 531 of 790
# Finished rate 532 of 790
# Finished rate 533 of 790
# Finished rate 534 of 790
# Finished rate 535 of 790
# Finished rate 536 of 790
# Finished rate 537 of 790
# Finished rate 538 of 790
# Finished rate 539 of 790
# Finished rate 540 of 790
# Finished rate 541 of 790
# Finished rate 542 of 790
# Finished rate 543 of 790
# Finished rate 544 of 790
# Finished rate 545 of 790
# Finished rate 546 of 790
# Finished rate 547 of 790
# Finished rate 548 of 790
# Finished rate 549 of 790
# Finished rate 550 of 790
# Finished rate 551 of 790
# Finished rate 552 of 790
# Finished rate 553 of 790
# Finished rate 554 of 790
# Finished rate 555 of 790
# Finished rate 556 of 790
# Finished rate 557 of 790
# Finished rate 558 of 790
# Finished rate 559 of 790
# Finished rate 560 of 790
# Finished rate 561 of 790
# Finished rate 562 of 790
# Finished rate 563 of 790
# Finished rate 564 of 790
# Finished rate 565 of 790
# Finished rate 566 of 790
# Finished rate 567 of 790
# Finished rate 568 of 790
# Finished rate 569 of 790
# Finished rate 570 of 790
# Finished rate 571 of 790
# Finished rate 572 of 790
# Finished rate 573 of 790
# Finished rate 574 of 790
# Finished rate 575 of 790
# Finished rate 576 of 790
# Finished rate 577 of 790
# Finished rate 578 of 790
# Finished rate 579 of 790
# Finished rate 580 of 790
# Finished rate 581 of 790
# Finished rate 582 of 790
# Finished rate 583 of 790
# Finished rate 584 of 790
# Finished rate 585 of 790
# Finished rate 586 of 790
# Finished rate 587 of 790
# Finished rate 588 of 790
# Finished rate 589 of 790
# Finished rate 590 of 790
# Finished rate 591 of 790
# Finished rate 592 of 790
# Finished rate 593 of 790
# Finished rate 594 of 790
# Finished rate 595 of 790
# Finished rate 596 of 790
# Finished rate 597 of 790
# Finished rate 598 of 790
# Finished rate 599 of 790
# Finished rate 600 of 790
# Finished rate 601 of 790
# Finished rate 602 of 790
# Finished rate 603 of 790
# Finished rate 604 of 790
# Finished rate 605 of 790
# Finished rate 606 of 790
# Finished rate 607 of 790
# Finished rate 608 of 790
# Finished rate 609 of 790
# Finished rate 610 of 790
# Finished rate 611 of 790
# Finished rate 612 of 790
# Finished rate 613 of 790
# Finished rate 614 of 790
# Finished rate 615 of 790
# Finished rate 616 of 790
# Finished rate 617 of 790
# Finished rate 618 of 790
# Finished rate 619 of 790
# Finished rate 620 of 790
# Finished rate 621 of 790
# Finished rate 622 of 790
# Finished rate 623 of 790
# Finished rate 624 of 790
# Finished rate 625 of 790
# Finished rate 626 of 790
# Finished rate 627 of 790
# Finished rate 628 of 790
# Finished rate 629 of 790
# Finished rate 630 of 790
# Finished rate 631 of 790
# Finished rate 632 of 790
# Finished rate 633 of 790
# Finished rate 634 of 790
# Finished rate 635 of 790
# Finished rate 636 of 790
# Finished rate 637 of 790
# Finished rate 638 of 790
# Finished rate 639 of 790
# Finished rate 640 of 790
# Finished rate 641 of 790
# Finished rate 642 of 790
# Finished rate 643 of 790
# Finished rate 644 of 790
# Finished rate 645 of 790
# Finished rate 646 of 790
# Finished rate 647 of 790
# Finished rate 648 of 790
# Finished rate 649 of 790
# Finished rate 650 of 790
# Finished rate 651 of 790
# Finished rate 652 of 790
# Finished rate 653 of 790
# Finished rate 654 of 790
# Finished rate 655 of 790
# Finished rate 656 of 790
# Finished rate 657 of 790
# Finished rate 658 of 790
# Finished rate 659 of 790
# Finished rate 660 of 790
# Finished rate 661 of 790
# Finished rate 662 of 790
# Finished rate 663 of 790
# Finished rate 664 of 790
# Finished rate 665 of 790
# Finished rate 666 of 790
# Finished rate 667 of 790
# Finished rate 668 of 790
# Finished rate 669 of 790
# Finished rate 670 of 790
# Finished rate 671 of 790
# Finished rate 672 of 790
# Finished rate 673 of 790
# Finished rate 674 of 790
# Finished rate 675 of 790
# Finished rate 676 of 790
# Finished rate 677 of 790
# Finished rate 678 of 790
# Finished rate 679 of 790
# Finished rate 680 of 790
# Finished rate 681 of 790
# Finished rate 682 of 790
# Finished rate 683 of 790
# Finished rate 684 of 790
# Finished rate 685 of 790
# Finished rate 686 of 790
# Finished rate 687 of 790
# Finished rate 688 of 790
# Finished rate 689 of 790
# Finished rate 690 of 790
# Finished rate 691 of 790
# Finished rate 692 of 790
# Finished rate 693 of 790
# Finished rate 694 of 790
# Finished rate 695 of 790
# Finished rate 696 of 790
# Finished rate 697 of 790
# Finished rate 698 of 790
# Finished rate 699 of 790
# Finished rate 700 of 790
# Finished rate 701 of 790
# Finished rate 702 of 790
# Finished rate 703 of 790
# Finished rate 704 of 790
# Finished rate 705 of 790
# Finished rate 706 of 790
# Finished rate 707 of 790
# Finished rate 708 of 790
# Finished rate 709 of 790
# Finished rate 710 of 790
# Finished rate 711 of 790
# Finished rate 712 of 790
# Finished rate 713 of 790
# Finished rate 714 of 790
# Finished rate 715 of 790
# Finished rate 716 of 790
# Finished rate 717 of 790
# Finished rate 718 of 790
# Finished rate 719 of 790
# Finished rate 720 of 790
# Finished rate 721 of 790
# Finished rate 722 of 790
# Finished rate 723 of 790
# Finished rate 724 of 790
# Finished rate 725 of 790
# Finished rate 726 of 790
# Finished rate 727 of 790
# Finished rate 728 of 790
# Finished rate 729 of 790
# Finished rate 730 of 790
# Finished rate 731 of 790
# Finished rate 732 of 790
# Finished rate 733 of 790
# Finished rate 734 of 790
# Finished rate 735 of 790
# Finished rate 736 of 790
# Finished rate 737 of 790
# Finished rate 738 of 790
# Finished rate 739 of 790
# Finished rate 740 of 790
# Finished rate 741 of 790
# Finished rate 742 of 790
# Finished rate 743 of 790
# Finished rate 744 of 790
# Finished rate 745 of 790
# Finished rate 746 of 790
# Finished rate 747 of 790
# Finished rate 748 of 790
# Finished rate 749 of 790
# Finished rate 750 of 790
# Finished rate 751 of 790
# Finished rate 752 of 790
# Finished rate 753 of 790
# Finished rate 754 of 790
# Finished rate 755 of 790
# Finished rate 756 of 790
# Finished rate 757 of 790
# Finished rate 758 of 790
# Finished rate 759 of 790
# Finished rate 760 of 790
# Finished rate 761 of 790
# Finished rate 762 of 790
# Finished rate 763 of 790
# Finished rate 764 of 790
# Finished rate 765 of 790
# Finished rate 766 of 790
# Finished rate 767 of 790
# Finished rate 768 of 790
# Finished rate 769 of 790
# Finished rate 770 of 790
# Finished rate 771 of 790
# Finished rate 772 of 790
# Finished rate 773 of 790
# Finished rate 774 of 790
# Finished rate 775 of 790
# Finished rate 776 of 790
# Finished rate 777 of 790
# Finished rate 778 of 790
# Finished rate 779 of 790
# Finished rate 780 of 790
# Finished rate 781 of 790
# Finished rate 782 of 790
# Finished rate 783 of 790
# Finished rate 784 of 790
# Finished rate 785 of 790
# Finished rate 786 of 790
# Finished rate 787 of 790
# Finished rate 788 of 790
# Finished rate 789 of 790

# %%
# plt.style.use('seaborn-dark')
jtplot.style()
# plt.style.use('classic')
plt.figure(figsize=(12,8))
plt.semilogy(frame_rates, snr_coded_list_10, 'b-')
plt.semilogy(frame_rates, snr_coded_list_50, 'g-')
plt.semilogy(frame_rates, snr_coded_list_99, 'y')
plt.semilogy(frame_rates, snr_sns_list, 'r-', linewidth=2)
plt.semilogy(frame_rates, snr_strobe_list, 'w-', linewidth=2)

plt.ylim((0.5, 5000))
plt.xlim((0,75))

plt.legend(('Coded, 5% Illuminated', 'Coded, 50% Illuminated', 'Coded, 95% Illuminated', 'Stop-and-Stare', 'Strobed'), fontsize=24)
plt.xlabel('Frame Rate (Hz)', fontsize=28)
plt.ylabel('SNR', fontsize=28)
ax = plt.gca()


for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(24) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(24)
    
plt.grid('on', which='both')
plt.tight_layout()
plt.savefig(figure_directory + 'strobe_sns_coded.png', transparent=True)

# %%
# plt.style.use('seaborn-dark')
jtplot.style()
# plt.style.use('classic')
plt.figure(figsize=(12,8))
plt.semilogy(frame_rates, snr_sns_list, 'r-', linewidth=2)
plt.semilogy(frame_rates, snr_strobe_list, 'w-', linewidth=2)

plt.ylim((0.5, 5000))
plt.xlim((0,75))

plt.legend(('Stop-and-Stare', 'Strobed'), fontsize=24)
plt.xlabel('Frame Rate (Hz)', fontsize=28)
plt.ylabel('SNR', fontsize=28)
ax = plt.gca()

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(24) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(24)
    


plt.grid('on', which='both')
plt.tight_layout()
plt.savefig(figure_directory + 'strobe_sns.png', transparent=True)

# %% [markdown]
# # Blur Kernel Optimization

# %%
data = np.load('single_illums.npz')
kernel_vector = data['kernel_vector']
kernel_random = data['kernel_random']
blur_kernel_map = np.zeros(object_size)

for position_index, position in enumerate(point_list):
    blur_kernel_map[position[0], position[1]] = kernel_vector[position_index]

# %%
num_frames = iterates.shape[1]

iterates = np.array(result['history']['x']) #.T
print(iterates.shape)
total_its = iterates.shape[1]
interval = total_its / num_frames
#interval=2
#ax = plt.subplot2grid((6, 1), (1, 5))
#ax = plt.subplot2grid((6, 1), (1, 0), colspan=5)

initial_power_spectrum = 0;
blur_operator = W * 0.5*np.sum(kernel_map, 0).astype(np.complex64).reshape(-1)
static_power_spectrum = np.sum(np.abs(wotf.Ft(blur_operator.reshape(image_size))), axis=0)

sigma_min_static = np.amin(static_power_spectrum)
sigma_min_static = np.amax(static_power_spectrum)

# Generate spatial frequency coordintes
ps = 6.5
fov = 2000 * 6.5e-3/20
dk = 1/fov
freqs = np.arange(-len(static_power_spectrum) // 2, len(static_power_spectrum) // 2) * dk
assert len(freqs) == len(static_power_spectrum)

kernel_random = iterates[:,0]

for i in range(num_frames):
    illum = iterates[:,int(interval*i)]

    blur_operator_illum = W * (kernel_map.T.dot(iterates[:,int(interval*i)])).T.astype(np.complex64).reshape(-1)
    power_spectrum = np.sum(np.abs(wotf.Ft(blur_operator_illum.reshape(image_size))), axis=0)
    sigma_min = np.amin(power_spectrum)
    sigma_max = np.amax(power_spectrum)
    condition = sigma_max/sigma_min
    
    if i==0:
        initial_power_spectrum = power_spectrum
    
    fig = plt.figure(figsize=(10,5))
    ax1 = plt.subplot2grid((8, 1), (0, 0), rowspan=4)
    ax2 = plt.subplot2grid((8, 1), (6, 0), rowspan=2)
    
    ax2.step(illum, 'orange', linewidth=3)
    ax2.set_ylim([-0.1,1.1])
    ax2.set_xlim([0,24])
    ax2.set_title('Illumination Pattern', fontsize=24, color='w')
    ax1.set_title('Power Spectrum', fontsize=24, color='w')
#     ax1.set_xlim([0,127])
#     ax1.set_ylim([10,10^4])
#     ax2.set_xticklabels([])
    ax1.set_ylabel('Energy', color='w')
    ax1.set_xlabel('Spatial Frequencey (cycles/mm)', color='w')
    
    ax2.set_ylabel('Intensity', color='w')
    ax2.set_xlabel('Position', color='w')
    
    ax2.xaxis.set_ticks_position('none')
    ax2.yaxis.set_ticks_position('none')
    #ax2.axison = False
    ax2.set_yticklabels([0,0,1])
#     ax1.semilogy(initial_power_spectrum, '--', color='white')
#     ax1.semilogy(static_power_spectrum, '--', color='white')
    ax1.semilogy(freqs, sigma_min*np.ones(power_spectrum.size), color='r', linewidth=3)
    ax1.semilogy(freqs, sigma_max*np.ones(power_spectrum.size), color='r', linewidth=3)
    ax1.semilogy(freqs, power_spectrum, color='blue', linewidth=3)
    ax1.set_ylim((10,6000))
#     ax1.set_xticklabels([])
    #ax1.set_yticklabels([])
    #plt.suptitle('iteration '+str(int(interval*i))+',\t$\kappa=$'+str(np.round(condition,3)))
    
    plt.text(0.6,4.7,'iteration '+str(int(interval*i))+', $\kappa=$'+str(np.round(condition,3)),fontsize=15, color='w')
    
    # Set Axis Colors
    for ax in [ax1, ax2]:
        ax.tick_params(axis='both', which='major', labelsize=14, color='w')
        ax.tick_params(axis='both', which='minor', labelsize=14, color='w')
        [i.set_color("w") for i in ax.get_xticklabels()]
        [i.set_color("w") for i in ax.get_yticklabels()]
    plt.savefig("images/power_spectrum_optimization" + str(i) + ".png")
